# %% [markdown]
# <a href="https://colab.research.google.com/github/KnzMcn/Attempts-At-Learning-CNN/blob/main/cnn_with_shuffle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from google.colab import drive
import zipfile
import os
from PIL import Image

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, Rescaling, Input
from keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Import the dataset

# %%
# mount google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# unzip the dataset file
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/3rd year/Machine Learning/Learning Evidence/Alzheimers.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# generate the image datasets
train_set = image_dataset_from_directory('/content/Alzheimers/train',
                                         label_mode = 'int',
                                         color_mode = 'grayscale',
                                         batch_size = 256, 
                                         image_size = (50, 50),  
                                         validation_split = 0.2,                                                                    
                                         subset = 'training',
                                         seed = 0,
                                         shuffle = True)

val_set = image_dataset_from_directory('/content/Alzheimers/train',
                                       label_mode = 'int',
                                       color_mode = 'grayscale',
                                       batch_size = 256,
                                       image_size = (50, 50),
                                       validation_split = 0.2,
                                       subset = 'validation',
                                       seed = 0,
                                       shuffle = True)

test_set = image_dataset_from_directory('/content/Alzheimers/test',
                                        label_mode = 'int',
                                        color_mode = 'grayscale',
                                        batch_size = 1279, 
                                        image_size = (50, 50), 
                                        shuffle = True)
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.
# Found 1279 files belonging to 4 classes.

# %%
# get the class names
class_names = train_set.class_names
class_names
# Out:
# ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
# display the images
plt.figure(figsize = (10, 10))
for images, labels in train_set.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(images[i].numpy().astype('float32').reshape(50, 50))
    plt.title(class_names[labels[i]])
    plt.axis('off')

# %%
# retrive the batches and labels of the train and test set
for batch, labels in train_set:
  print("Train set shape:\t", batch.shape, labels.shape)
  break

for batch, labels in train_set:
  print("Train set shape:\t", batch.shape, labels.shape)
  break

for batch, labels in test_set:
  test_labels = labels
  print("Test set shape:\t\t", batch.shape, test_labels.shape)
  break
# Out:
# Train set shape: (256, 50, 50, 1) (256,)
# Test set shape: (1279, 50, 50, 1) (1279,)

# %% [markdown]
# # Preprocessing

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_set = train_set.cache().prefetch(buffer_size = AUTOTUNE)
val_set = val_set.cache().prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# # Convolutional Neural Network

# %%
# state the number of classes and input shape
num_classes = 4
input_img = (50, 50, 1)

# %%
# build the network
cnn = Sequential([Input(shape = input_img), 
                  Rescaling(1./255),

                  #Conv2D(128, kernel_size = 3, activation = 'relu', padding = 'same'),
                  Conv2D(256, kernel_size = 3, activation = 'relu', padding = 'same'),
                  MaxPooling2D(2),
                  Dropout(0.75),

                  Flatten(),
                  #Dense(128, activation = 'relu'),
                  Dropout(0.50),
                  Dense(num_classes, activation = 'softmax')])

# %%
# compile the network
cnn.compile(loss = 'sparse_categorical_crossentropy',
            optimizer = 'adam',
            metrics = ['accuracy'])
cnn.build(input_img)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 50, 50, 1)         0
#
#  conv2d (Conv2D)             (None, 50, 50, 256)       2560
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 256)      0
#  )
#
#  dropout (Dropout)           (None, 25, 25, 256)       0
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dropout_1 (Dropout)         (None, 160000)            0
#
#  dense (Dense)               (None, 4)                 640004
#
# =================================================================
# Total params: 642,564
# Trainable params: 642,564
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model using the Generator

# %%
cnn_history = cnn.fit(train_set,
                      epochs = 130, 
                      verbose = 1,
                      validation_data = val_set)
# Out:
# Epoch 1/130
# 17/17 [==============================] - 49s 3s/step - loss: 1.1104 - accuracy: 0.4779 - val_loss: 1.0201 - val_accuracy: 0.5381
# Epoch 2/130
# 17/17 [==============================] - 42s 2s/step - loss: 0.9871 - accuracy: 0.5411 - val_loss: 0.9677 - val_accuracy: 0.5684
# Epoch 3/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.9368 - accuracy: 0.5629 - val_loss: 0.9320 - val_accuracy: 0.5850
# Epoch 4/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.9015 - accuracy: 0.5702 - val_loss: 0.9486 - val_accuracy: 0.5674
# Epoch 5/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.8946 - accuracy: 0.5760 - val_loss: 0.9151 - val_accuracy: 0.5752
# Epoch 6/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.8709 - accuracy: 0.5904 - val_loss: 0.8864 - val_accuracy: 0.5977
# Epoch 7/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.8580 - accuracy: 0.6002 - val_loss: 0.8624 - val_accuracy: 0.6074
# Epoch 8/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.8483 - accuracy: 0.6109 - val_loss: 0.8479 - val_accuracy: 0.6191
# Epoch 9/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.8359 - accuracy: 0.6122 - val_loss: 0.8353 - val_accuracy: 0.6270
# Epoch 10/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.8218 - accuracy: 0.6202 - val_loss: 0.8231 - val_accuracy: 0.6172
# Epoch 11/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.8134 - accuracy: 0.6224 - val_loss: 0.7933 - val_accuracy: 0.6289
# Epoch 12/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.7854 - accuracy: 0.6424 - val_loss: 0.7654 - val_accuracy: 0.6729
# Epoch 13/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.7571 - accuracy: 0.6561 - val_loss: 0.7453 - val_accuracy: 0.7002
# Epoch 14/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.7302 - accuracy: 0.6790 - val_loss: 0.7299 - val_accuracy: 0.6895
# Epoch 15/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.7169 - accuracy: 0.6837 - val_loss: 0.7217 - val_accuracy: 0.7109
# Epoch 16/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.7099 - accuracy: 0.6854 - val_loss: 0.7046 - val_accuracy: 0.6943
# Epoch 17/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.7061 - accuracy: 0.6837 - val_loss: 0.6971 - val_accuracy: 0.7197
# Epoch 18/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.6882 - accuracy: 0.6922 - val_loss: 0.6779 - val_accuracy: 0.7246
# Epoch 19/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.6579 - accuracy: 0.7120 - val_loss: 0.6619 - val_accuracy: 0.7607
# Epoch 20/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.6425 - accuracy: 0.7293 - val_loss: 0.6465 - val_accuracy: 0.7627
# Epoch 21/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.6359 - accuracy: 0.7293 - val_loss: 0.6325 - val_accuracy: 0.7607
# Epoch 22/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.6071 - accuracy: 0.7449 - val_loss: 0.6158 - val_accuracy: 0.7744
# Epoch 23/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.5967 - accuracy: 0.7474 - val_loss: 0.6012 - val_accuracy: 0.7734
# Epoch 24/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.5745 - accuracy: 0.7637 - val_loss: 0.5911 - val_accuracy: 0.7734
# Epoch 25/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.5716 - accuracy: 0.7693 - val_loss: 0.5729 - val_accuracy: 0.7988
# Epoch 26/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.5491 - accuracy: 0.7757 - val_loss: 0.5607 - val_accuracy: 0.8008
# Epoch 27/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.5535 - accuracy: 0.7671 - val_loss: 0.5554 - val_accuracy: 0.7939
# Epoch 28/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.5335 - accuracy: 0.7872 - val_loss: 0.5501 - val_accuracy: 0.7891
# Epoch 29/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.5255 - accuracy: 0.7845 - val_loss: 0.5448 - val_accuracy: 0.7891
# Epoch 30/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.5184 - accuracy: 0.7859 - val_loss: 0.5344 - val_accuracy: 0.8086
# Epoch 31/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.5064 - accuracy: 0.7977 - val_loss: 0.5090 - val_accuracy: 0.8369
# Epoch 32/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.4923 - accuracy: 0.8006 - val_loss: 0.5045 - val_accuracy: 0.8281
# Epoch 33/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4873 - accuracy: 0.8072 - val_loss: 0.4916 - val_accuracy: 0.8369
# Epoch 34/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.4776 - accuracy: 0.8089 - val_loss: 0.4922 - val_accuracy: 0.8242
# Epoch 35/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.4664 - accuracy: 0.8162 - val_loss: 0.4748 - val_accuracy: 0.8428
# Epoch 36/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.4565 - accuracy: 0.8177 - val_loss: 0.4717 - val_accuracy: 0.8477
# Epoch 37/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.4476 - accuracy: 0.8191 - val_loss: 0.4725 - val_accuracy: 0.8369
# Epoch 38/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.4296 - accuracy: 0.8274 - val_loss: 0.4633 - val_accuracy: 0.8301
# Epoch 39/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.4306 - accuracy: 0.8318 - val_loss: 0.4572 - val_accuracy: 0.8271
# Epoch 40/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4216 - accuracy: 0.8343 - val_loss: 0.4328 - val_accuracy: 0.8770
# Epoch 41/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.4097 - accuracy: 0.8443 - val_loss: 0.4317 - val_accuracy: 0.8555
# Epoch 42/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.3996 - accuracy: 0.8445 - val_loss: 0.4232 - val_accuracy: 0.8613
# Epoch 43/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.3995 - accuracy: 0.8467 - val_loss: 0.4139 - val_accuracy: 0.8740
# Epoch 44/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.4037 - accuracy: 0.8465 - val_loss: 0.4029 - val_accuracy: 0.8887
# Epoch 45/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.3848 - accuracy: 0.8570 - val_loss: 0.3944 - val_accuracy: 0.8857
# Epoch 46/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3809 - accuracy: 0.8504 - val_loss: 0.3884 - val_accuracy: 0.8867
# Epoch 47/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.3738 - accuracy: 0.8579 - val_loss: 0.3782 - val_accuracy: 0.9043
# Epoch 48/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.3622 - accuracy: 0.8682 - val_loss: 0.3760 - val_accuracy: 0.8936
# Epoch 49/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.3692 - accuracy: 0.8582 - val_loss: 0.3828 - val_accuracy: 0.8721
# Epoch 50/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.3558 - accuracy: 0.8645 - val_loss: 0.3596 - val_accuracy: 0.9131
# Epoch 51/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.3493 - accuracy: 0.8714 - val_loss: 0.3664 - val_accuracy: 0.8936
# Epoch 52/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3436 - accuracy: 0.8682 - val_loss: 0.3470 - val_accuracy: 0.9180
# Epoch 53/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.3360 - accuracy: 0.8763 - val_loss: 0.3448 - val_accuracy: 0.9092
# Epoch 54/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.3409 - accuracy: 0.8728 - val_loss: 0.3497 - val_accuracy: 0.8936
# Epoch 55/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3249 - accuracy: 0.8858 - val_loss: 0.3452 - val_accuracy: 0.8965
# Epoch 56/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.3288 - accuracy: 0.8797 - val_loss: 0.3516 - val_accuracy: 0.8887
# Epoch 57/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.3321 - accuracy: 0.8763 - val_loss: 0.3440 - val_accuracy: 0.8936
# Epoch 58/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3261 - accuracy: 0.8787 - val_loss: 0.3243 - val_accuracy: 0.9072
# Epoch 59/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.3162 - accuracy: 0.8843 - val_loss: 0.3207 - val_accuracy: 0.9199
# Epoch 60/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3114 - accuracy: 0.8816 - val_loss: 0.3081 - val_accuracy: 0.9248
# Epoch 61/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.3070 - accuracy: 0.8870 - val_loss: 0.3030 - val_accuracy: 0.9199
# Epoch 62/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2970 - accuracy: 0.8897 - val_loss: 0.3102 - val_accuracy: 0.9160
# Epoch 63/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2953 - accuracy: 0.8953 - val_loss: 0.2969 - val_accuracy: 0.9248
# Epoch 64/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2798 - accuracy: 0.9048 - val_loss: 0.2974 - val_accuracy: 0.9160
# Epoch 65/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2919 - accuracy: 0.8914 - val_loss: 0.3134 - val_accuracy: 0.8945
# Epoch 66/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.3060 - accuracy: 0.8848 - val_loss: 0.2846 - val_accuracy: 0.9316
# Epoch 67/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2862 - accuracy: 0.8950 - val_loss: 0.2775 - val_accuracy: 0.9336
# Epoch 68/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.2796 - accuracy: 0.9029 - val_loss: 0.2732 - val_accuracy: 0.9297
# Epoch 69/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2731 - accuracy: 0.8999 - val_loss: 0.2733 - val_accuracy: 0.9238
# Epoch 70/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2714 - accuracy: 0.9031 - val_loss: 0.2645 - val_accuracy: 0.9316
# Epoch 71/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2552 - accuracy: 0.9063 - val_loss: 0.2668 - val_accuracy: 0.9238
# Epoch 72/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2465 - accuracy: 0.9146 - val_loss: 0.2524 - val_accuracy: 0.9336
# Epoch 73/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2734 - accuracy: 0.9014 - val_loss: 0.2598 - val_accuracy: 0.9355
# Epoch 74/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.2511 - accuracy: 0.9097 - val_loss: 0.2523 - val_accuracy: 0.9443
# Epoch 75/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2539 - accuracy: 0.9058 - val_loss: 0.2459 - val_accuracy: 0.9424
# Epoch 76/130
# 17/17 [==============================] - 44s 3s/step - loss: 0.2455 - accuracy: 0.9090 - val_loss: 0.2404 - val_accuracy: 0.9443
# Epoch 77/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2426 - accuracy: 0.9116 - val_loss: 0.2538 - val_accuracy: 0.9297
# Epoch 78/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.2427 - accuracy: 0.9112 - val_loss: 0.2340 - val_accuracy: 0.9473
# Epoch 79/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2468 - accuracy: 0.9109 - val_loss: 0.2370 - val_accuracy: 0.9463
# Epoch 80/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2358 - accuracy: 0.9175 - val_loss: 0.2344 - val_accuracy: 0.9443
# Epoch 81/130
# 17/17 [==============================] - 45s 3s/step - loss: 0.2477 - accuracy: 0.9107 - val_loss: 0.2280 - val_accuracy: 0.9502
# Epoch 82/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.2243 - accuracy: 0.9224 - val_loss: 0.2232 - val_accuracy: 0.9502
# Epoch 83/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.2360 - accuracy: 0.9177 - val_loss: 0.2248 - val_accuracy: 0.9414
# Epoch 84/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2191 - accuracy: 0.9229 - val_loss: 0.2175 - val_accuracy: 0.9482
# Epoch 85/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.2388 - accuracy: 0.9104 - val_loss: 0.2211 - val_accuracy: 0.9414
# Epoch 86/130
# 17/17 [==============================] - 58s 3s/step - loss: 0.2212 - accuracy: 0.9231 - val_loss: 0.2139 - val_accuracy: 0.9434
# Epoch 87/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2162 - accuracy: 0.9253 - val_loss: 0.2137 - val_accuracy: 0.9482
# Epoch 88/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.2136 - accuracy: 0.9287 - val_loss: 0.2083 - val_accuracy: 0.9561
# Epoch 89/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.2241 - accuracy: 0.9214 - val_loss: 0.2108 - val_accuracy: 0.9473
# Epoch 90/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.2138 - accuracy: 0.9248 - val_loss: 0.2065 - val_accuracy: 0.9561
# Epoch 91/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2122 - accuracy: 0.9287 - val_loss: 0.2048 - val_accuracy: 0.9541
# Epoch 92/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.2120 - accuracy: 0.9258 - val_loss: 0.1994 - val_accuracy: 0.9521
# Epoch 93/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2108 - accuracy: 0.9297 - val_loss: 0.1966 - val_accuracy: 0.9561
# Epoch 94/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2145 - accuracy: 0.9219 - val_loss: 0.1968 - val_accuracy: 0.9561
# Epoch 95/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.2080 - accuracy: 0.9278 - val_loss: 0.2026 - val_accuracy: 0.9434
# Epoch 96/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1983 - accuracy: 0.9307 - val_loss: 0.1932 - val_accuracy: 0.9551
# Epoch 97/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2007 - accuracy: 0.9329 - val_loss: 0.1915 - val_accuracy: 0.9590
# Epoch 98/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.2033 - accuracy: 0.9287 - val_loss: 0.1855 - val_accuracy: 0.9590
# Epoch 99/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1922 - accuracy: 0.9365 - val_loss: 0.1844 - val_accuracy: 0.9531
# Epoch 100/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1903 - accuracy: 0.9324 - val_loss: 0.1832 - val_accuracy: 0.9570
# Epoch 101/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1927 - accuracy: 0.9336 - val_loss: 0.1842 - val_accuracy: 0.9541
# Epoch 102/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1975 - accuracy: 0.9290 - val_loss: 0.1766 - val_accuracy: 0.9600
# Epoch 103/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1902 - accuracy: 0.9290 - val_loss: 0.1750 - val_accuracy: 0.9600
# Epoch 104/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1913 - accuracy: 0.9302 - val_loss: 0.2048 - val_accuracy: 0.9355
# Epoch 105/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1970 - accuracy: 0.9280 - val_loss: 0.1769 - val_accuracy: 0.9609
# Epoch 106/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.1890 - accuracy: 0.9351 - val_loss: 0.1689 - val_accuracy: 0.9678
# Epoch 107/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1731 - accuracy: 0.9397 - val_loss: 0.1653 - val_accuracy: 0.9609
# Epoch 108/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1734 - accuracy: 0.9390 - val_loss: 0.1648 - val_accuracy: 0.9668
# Epoch 109/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1752 - accuracy: 0.9353 - val_loss: 0.1630 - val_accuracy: 0.9688
# Epoch 110/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1864 - accuracy: 0.9302 - val_loss: 0.1657 - val_accuracy: 0.9648
# Epoch 111/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1888 - accuracy: 0.9321 - val_loss: 0.1669 - val_accuracy: 0.9658
# Epoch 112/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1807 - accuracy: 0.9378 - val_loss: 0.1614 - val_accuracy: 0.9688
# Epoch 113/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1734 - accuracy: 0.9378 - val_loss: 0.1721 - val_accuracy: 0.9570
# Epoch 114/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1703 - accuracy: 0.9419 - val_loss: 0.1602 - val_accuracy: 0.9639
# Epoch 115/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.1690 - accuracy: 0.9404 - val_loss: 0.1558 - val_accuracy: 0.9688
# Epoch 116/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1599 - accuracy: 0.9456 - val_loss: 0.1527 - val_accuracy: 0.9668
# Epoch 117/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1701 - accuracy: 0.9436 - val_loss: 0.1557 - val_accuracy: 0.9658
# Epoch 118/130
# 17/17 [==============================] - 46s 3s/step - loss: 0.1667 - accuracy: 0.9458 - val_loss: 0.1589 - val_accuracy: 0.9668
# Epoch 119/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.1743 - accuracy: 0.9392 - val_loss: 0.1542 - val_accuracy: 0.9668
# Epoch 120/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1679 - accuracy: 0.9404 - val_loss: 0.1548 - val_accuracy: 0.9668
# Epoch 121/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1561 - accuracy: 0.9485 - val_loss: 0.1480 - val_accuracy: 0.9697
# Epoch 122/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1558 - accuracy: 0.9475 - val_loss: 0.1485 - val_accuracy: 0.9717
# Epoch 123/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1579 - accuracy: 0.9439 - val_loss: 0.1432 - val_accuracy: 0.9697
# Epoch 124/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1636 - accuracy: 0.9409 - val_loss: 0.1462 - val_accuracy: 0.9668
# Epoch 125/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1528 - accuracy: 0.9446 - val_loss: 0.1433 - val_accuracy: 0.9697
# Epoch 126/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.1566 - accuracy: 0.9456 - val_loss: 0.1411 - val_accuracy: 0.9707
# Epoch 127/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1527 - accuracy: 0.9492 - val_loss: 0.1427 - val_accuracy: 0.9639
# Epoch 128/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1569 - accuracy: 0.9446 - val_loss: 0.1381 - val_accuracy: 0.9717
# Epoch 129/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.1535 - accuracy: 0.9470 - val_loss: 0.1364 - val_accuracy: 0.9717
# Epoch 130/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.1499 - accuracy: 0.9502 - val_loss: 0.1388 - val_accuracy: 0.9697

# %%
# save the model
cnn.save('cnn.h5')

# %% [markdown]
# # Visualization

# %%
#visualization of the model evaluation
#plot image will change with more epochs
accuracy = cnn_history.history['accuracy']
val_accuracy = cnn_history.history['val_accuracy']
loss = cnn_history.history['loss']
val_loss = cnn_history.history['val_loss']
epochs = range(len(accuracy))

#Visualize the accuracy
plt.plot(epochs, accuracy, 'b', c = 'blue', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'b', c = 'orange', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.figure()

#Visualize the loss
plt.plot(epochs, loss, 'b', c = 'blue', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', c = 'orange', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluation

# %%
test_eval = cnn.evaluate(test_set, verbose = 0)

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 1.1684980392456055
# Test accuracy: 0.6145426034927368

# %% [markdown]
# # Classification Report

# %%
pred_classes = cnn.predict(test_set)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
pred_classes = np.argmax(np.round(pred_classes), axis = 1)

# %%
#create a classification report
target_names = ['Class {}'.format(i) for i in range(4)]
print(classification_report(test_labels, pred_classes, target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.09      0.03      0.04       179
#      Class 1       0.00      0.00      0.00        12
#      Class 2       0.51      0.48      0.49       640
#      Class 3       0.34      0.47      0.40       448
#
#     accuracy                           0.41      1279
#    macro avg       0.24      0.24      0.23      1279
# weighted avg       0.39      0.41      0.39      1279

# %% [markdown]
# # Confusion Matrix

# %%
# create confusion matrix
cm = confusion_matrix(test_labels, pred_classes)

# %%
# create a heatmap
plt.figure(figsize=(9, 9))

sns.heatmap(cm, 
            annot = True, 
            fmt = ".2f",
            square = True,
            yticklabels = class_names, 
            xticklabels = class_names)
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
all_sample_title = f'Model Accuracy Score: {test_eval[1]:.2%}'
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Model Accuracy Score: 61.45%')
