# %% [markdown]
# <a href="https://colab.research.google.com/github/KnzMcn/Attempts-At-Learning-CNN/blob/main/cnn_with_shuffle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from google.colab import drive
import zipfile
import os
from PIL import Image

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, Rescaling, Input
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Import the dataset

# %%
# mount google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# unzip the dataset file
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/3rd year/Machine Learning/Learning Evidence/Alzheimers.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# generate the image datasets
train_set = image_dataset_from_directory('/content/Alzheimers/train',
                                         label_mode = 'int',
                                         color_mode = 'grayscale',
                                         batch_size = 256, 
                                         image_size = (100, 100),  
                                         validation_split = 0.2,                                                                    
                                         subset = 'training',
                                         seed = 0,
                                         shuffle = True)

val_set = image_dataset_from_directory('/content/Alzheimers/train',
                                       label_mode = 'int',
                                       color_mode = 'grayscale',
                                       batch_size = 256,
                                       image_size = (100, 100),
                                       validation_split = 0.2,
                                       subset = 'validation',
                                       seed = 0,
                                       shuffle = True)

test_set = image_dataset_from_directory('/content/Alzheimers/test',
                                        label_mode = 'int',
                                        color_mode = 'grayscale',
                                        batch_size = 1279, 
                                        image_size = (100, 100), 
                                        shuffle = True)
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.
# Found 1279 files belonging to 4 classes.

# %%
# get the class names
class_names = train_set.class_names
class_names
# Out:
# ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
# display the images
plt.figure(figsize = (10, 10))
for images, labels in train_set.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(images[i].numpy().astype('float32').reshape(100, 100))
    plt.title(class_names[labels[i]])
    plt.axis('off')

# %%
# retrive the batches and labels of the train and test set
for batch, labels in train_set:
  print("Train set shape:", batch.shape, labels.shape)
  break

for batch, labels in test_set:
  test_labels = labels
  print("Test set shape:", batch.shape, test_labels.shape)
  break
# Out:
# Train set shape: (256, 100, 100, 1) (256,)
# Test set shape: (1279, 100, 100, 1) (1279,)

# %% [markdown]
# # Preprocessing

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_set = train_set.cache().prefetch(buffer_size = AUTOTUNE)
test_set = test_set.cache().prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# # Convolutional Neural Network

# %%
# state the number of classes and input shape
num_classes = 4
input_img = (100, 100, 1)

# %%
# build the network
cnn = Sequential([Input(shape = input_img), 
                  Rescaling(1./255),             

                  Conv2D(128, kernel_size = 3, activation = 'relu', padding = 'same'),
                  MaxPooling2D(2),
                  Dropout(0.75),

                  Flatten(),
                  Dense(128, activation = 'relu'),
                  Dropout(0.50),
                  Dense(num_classes, activation = 'softmax')])

# %%
# compile the network
cnn.compile(loss = 'sparse_categorical_crossentropy',
            optimizer = 'adam',
            metrics = ['accuracy'])
cnn.build(input_img)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 100, 100, 1)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 128)     1280
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 128)      0
#  )
#
#  dropout (Dropout)           (None, 50, 50, 128)       0
#
#  flatten (Flatten)           (None, 320000)            0
#
#  dense (Dense)               (None, 128)               40960128
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 40,961,924
# Trainable params: 40,961,924
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model using the Generator

# %%
cnn_history = cnn.fit(train_set,
                      epochs = 130, 
                      verbose = 1,
                      validation_data = val_set)
# Out:
# Epoch 1/130
# 17/17 [==============================] - 107s 6s/step - loss: 4.4734 - accuracy: 0.3981 - val_loss: 1.1176 - val_accuracy: 0.3467
# Epoch 2/130
# 17/17 [==============================] - 98s 6s/step - loss: 1.0801 - accuracy: 0.4945 - val_loss: 1.0358 - val_accuracy: 0.5020
# Epoch 3/130
# 17/17 [==============================] - 97s 6s/step - loss: 1.0462 - accuracy: 0.4948 - val_loss: 1.0101 - val_accuracy: 0.5020
# Epoch 4/130
# 17/17 [==============================] - 94s 6s/step - loss: 1.0312 - accuracy: 0.5023 - val_loss: 1.0003 - val_accuracy: 0.5020
# Epoch 5/130
# 17/17 [==============================] - 101s 6s/step - loss: 1.0155 - accuracy: 0.5033 - val_loss: 0.9851 - val_accuracy: 0.5127
# Epoch 6/130
# 17/17 [==============================] - 97s 6s/step - loss: 0.9955 - accuracy: 0.5162 - val_loss: 0.9611 - val_accuracy: 0.5234
# Epoch 7/130
# 17/17 [==============================] - 98s 6s/step - loss: 0.9701 - accuracy: 0.5355 - val_loss: 0.9374 - val_accuracy: 0.5713
# Epoch 8/130
# 17/17 [==============================] - 98s 6s/step - loss: 0.9559 - accuracy: 0.5362 - val_loss: 0.9273 - val_accuracy: 0.5811
# Epoch 9/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.9306 - accuracy: 0.5372 - val_loss: 0.8890 - val_accuracy: 0.5801
# Epoch 10/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.9032 - accuracy: 0.5592 - val_loss: 0.8770 - val_accuracy: 0.5898
# Epoch 11/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.8787 - accuracy: 0.5773 - val_loss: 0.8497 - val_accuracy: 0.6045
# Epoch 12/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.8332 - accuracy: 0.6068 - val_loss: 0.8340 - val_accuracy: 0.6006
# Epoch 13/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.8256 - accuracy: 0.6061 - val_loss: 0.8088 - val_accuracy: 0.6074
# Epoch 14/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.7902 - accuracy: 0.6300 - val_loss: 0.7704 - val_accuracy: 0.6426
# Epoch 15/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.7536 - accuracy: 0.6485 - val_loss: 0.7362 - val_accuracy: 0.6797
# Epoch 16/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.7148 - accuracy: 0.6817 - val_loss: 0.7027 - val_accuracy: 0.6934
# Epoch 17/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.6688 - accuracy: 0.7081 - val_loss: 0.6668 - val_accuracy: 0.6826
# Epoch 18/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.6370 - accuracy: 0.7322 - val_loss: 0.6113 - val_accuracy: 0.7832
# Epoch 19/130
# 17/17 [==============================] - 109s 6s/step - loss: 0.6090 - accuracy: 0.7415 - val_loss: 0.5770 - val_accuracy: 0.8066
# Epoch 20/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.5555 - accuracy: 0.7837 - val_loss: 0.5403 - val_accuracy: 0.7881
# Epoch 21/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.5253 - accuracy: 0.7933 - val_loss: 0.5134 - val_accuracy: 0.8418
# Epoch 22/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.5124 - accuracy: 0.8025 - val_loss: 0.4664 - val_accuracy: 0.8330
# Epoch 23/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.4727 - accuracy: 0.8296 - val_loss: 0.4428 - val_accuracy: 0.8545
# Epoch 24/130
# 17/17 [==============================] - 107s 6s/step - loss: 0.4422 - accuracy: 0.8309 - val_loss: 0.4331 - val_accuracy: 0.8809
# Epoch 25/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.4138 - accuracy: 0.8396 - val_loss: 0.3767 - val_accuracy: 0.8711
# Epoch 26/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.3818 - accuracy: 0.8638 - val_loss: 0.3476 - val_accuracy: 0.8916
# Epoch 27/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.3515 - accuracy: 0.8726 - val_loss: 0.3190 - val_accuracy: 0.9004
# Epoch 28/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.3450 - accuracy: 0.8726 - val_loss: 0.3196 - val_accuracy: 0.9170
# Epoch 29/130
# 17/17 [==============================] - 107s 6s/step - loss: 0.3398 - accuracy: 0.8806 - val_loss: 0.2885 - val_accuracy: 0.9141
# Epoch 30/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.3039 - accuracy: 0.8919 - val_loss: 0.2784 - val_accuracy: 0.9160
# Epoch 31/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.2948 - accuracy: 0.8926 - val_loss: 0.2512 - val_accuracy: 0.9219
# Epoch 32/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.2804 - accuracy: 0.9004 - val_loss: 0.2244 - val_accuracy: 0.9346
# Epoch 33/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.2759 - accuracy: 0.9024 - val_loss: 0.2137 - val_accuracy: 0.9404
# Epoch 34/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.2448 - accuracy: 0.9112 - val_loss: 0.2012 - val_accuracy: 0.9424
# Epoch 35/130
# 17/17 [==============================] - 107s 6s/step - loss: 0.2315 - accuracy: 0.9197 - val_loss: 0.1928 - val_accuracy: 0.9414
# Epoch 36/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.2294 - accuracy: 0.9155 - val_loss: 0.3713 - val_accuracy: 0.8301
# Epoch 37/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.3750 - accuracy: 0.8487 - val_loss: 0.2308 - val_accuracy: 0.9336
# Epoch 38/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.2861 - accuracy: 0.8972 - val_loss: 0.1995 - val_accuracy: 0.9531
# Epoch 39/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.2294 - accuracy: 0.9204 - val_loss: 0.1722 - val_accuracy: 0.9609
# Epoch 40/130
# 17/17 [==============================] - 107s 6s/step - loss: 0.2349 - accuracy: 0.9197 - val_loss: 0.1714 - val_accuracy: 0.9531
# Epoch 41/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.2282 - accuracy: 0.9209 - val_loss: 0.1727 - val_accuracy: 0.9463
# Epoch 42/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.2097 - accuracy: 0.9307 - val_loss: 0.1533 - val_accuracy: 0.9658
# Epoch 43/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1878 - accuracy: 0.9378 - val_loss: 0.1476 - val_accuracy: 0.9717
# Epoch 44/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1909 - accuracy: 0.9392 - val_loss: 0.1521 - val_accuracy: 0.9541
# Epoch 45/130
# 17/17 [==============================] - 108s 6s/step - loss: 0.1884 - accuracy: 0.9368 - val_loss: 0.1370 - val_accuracy: 0.9746
# Epoch 46/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1853 - accuracy: 0.9375 - val_loss: 0.1192 - val_accuracy: 0.9756
# Epoch 47/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.1691 - accuracy: 0.9448 - val_loss: 0.1365 - val_accuracy: 0.9551
# Epoch 48/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1868 - accuracy: 0.9343 - val_loss: 0.1257 - val_accuracy: 0.9668
# Epoch 49/130
# 17/17 [==============================] - 105s 6s/step - loss: 0.1695 - accuracy: 0.9470 - val_loss: 0.1118 - val_accuracy: 0.9707
# Epoch 50/130
# 17/17 [==============================] - 98s 6s/step - loss: 0.1658 - accuracy: 0.9446 - val_loss: 0.1044 - val_accuracy: 0.9795
# Epoch 51/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1401 - accuracy: 0.9534 - val_loss: 0.1002 - val_accuracy: 0.9785
# Epoch 52/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.1525 - accuracy: 0.9490 - val_loss: 0.0953 - val_accuracy: 0.9785
# Epoch 53/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.1349 - accuracy: 0.9583 - val_loss: 0.0867 - val_accuracy: 0.9795
# Epoch 54/130
# 17/17 [==============================] - 105s 6s/step - loss: 0.1325 - accuracy: 0.9605 - val_loss: 0.0835 - val_accuracy: 0.9814
# Epoch 55/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.1274 - accuracy: 0.9612 - val_loss: 0.0844 - val_accuracy: 0.9854
# Epoch 56/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1267 - accuracy: 0.9580 - val_loss: 0.0823 - val_accuracy: 0.9834
# Epoch 57/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1229 - accuracy: 0.9636 - val_loss: 0.0715 - val_accuracy: 0.9854
# Epoch 58/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.1187 - accuracy: 0.9612 - val_loss: 0.0751 - val_accuracy: 0.9834
# Epoch 59/130
# 17/17 [==============================] - 106s 6s/step - loss: 0.1179 - accuracy: 0.9629 - val_loss: 0.0715 - val_accuracy: 0.9863
# Epoch 60/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1152 - accuracy: 0.9624 - val_loss: 0.0714 - val_accuracy: 0.9863
# Epoch 61/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1144 - accuracy: 0.9651 - val_loss: 0.0734 - val_accuracy: 0.9854
# Epoch 62/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.1264 - accuracy: 0.9614 - val_loss: 0.0710 - val_accuracy: 0.9854
# Epoch 63/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1163 - accuracy: 0.9658 - val_loss: 0.0768 - val_accuracy: 0.9824
# Epoch 64/130
# 17/17 [==============================] - 106s 6s/step - loss: 0.1217 - accuracy: 0.9595 - val_loss: 0.0673 - val_accuracy: 0.9863
# Epoch 65/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.1056 - accuracy: 0.9688 - val_loss: 0.0657 - val_accuracy: 0.9854
# Epoch 66/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.1106 - accuracy: 0.9663 - val_loss: 0.0657 - val_accuracy: 0.9854
# Epoch 67/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1104 - accuracy: 0.9668 - val_loss: 0.0577 - val_accuracy: 0.9883
# Epoch 68/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1011 - accuracy: 0.9692 - val_loss: 0.0568 - val_accuracy: 0.9873
# Epoch 69/130
# 17/17 [==============================] - 104s 6s/step - loss: 0.0982 - accuracy: 0.9710 - val_loss: 0.0579 - val_accuracy: 0.9873
# Epoch 70/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0983 - accuracy: 0.9688 - val_loss: 0.0552 - val_accuracy: 0.9883
# Epoch 71/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0999 - accuracy: 0.9695 - val_loss: 0.0540 - val_accuracy: 0.9893
# Epoch 72/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0929 - accuracy: 0.9729 - val_loss: 0.0606 - val_accuracy: 0.9873
# Epoch 73/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0892 - accuracy: 0.9714 - val_loss: 0.0708 - val_accuracy: 0.9775
# Epoch 74/130
# 17/17 [==============================] - 110s 6s/step - loss: 0.0909 - accuracy: 0.9722 - val_loss: 0.0523 - val_accuracy: 0.9893
# Epoch 75/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0938 - accuracy: 0.9663 - val_loss: 0.0787 - val_accuracy: 0.9814
# Epoch 76/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1898 - accuracy: 0.9336 - val_loss: 0.0712 - val_accuracy: 0.9844
# Epoch 77/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.1384 - accuracy: 0.9512 - val_loss: 0.0698 - val_accuracy: 0.9893
# Epoch 78/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.1597 - accuracy: 0.9448 - val_loss: 0.0783 - val_accuracy: 0.9824
# Epoch 79/130
# 17/17 [==============================] - 109s 6s/step - loss: 0.1296 - accuracy: 0.9602 - val_loss: 0.0653 - val_accuracy: 0.9883
# Epoch 80/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.1035 - accuracy: 0.9678 - val_loss: 0.0605 - val_accuracy: 0.9883
# Epoch 81/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.1046 - accuracy: 0.9658 - val_loss: 0.0555 - val_accuracy: 0.9883
# Epoch 82/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0909 - accuracy: 0.9729 - val_loss: 0.0517 - val_accuracy: 0.9893
# Epoch 83/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0860 - accuracy: 0.9749 - val_loss: 0.0515 - val_accuracy: 0.9883
# Epoch 84/130
# 17/17 [==============================] - 105s 6s/step - loss: 0.0985 - accuracy: 0.9692 - val_loss: 0.0471 - val_accuracy: 0.9922
# Epoch 85/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0882 - accuracy: 0.9734 - val_loss: 0.0640 - val_accuracy: 0.9795
# Epoch 86/130
# 17/17 [==============================] - 106s 6s/step - loss: 0.0908 - accuracy: 0.9761 - val_loss: 0.0460 - val_accuracy: 0.9922
# Epoch 87/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.0825 - accuracy: 0.9744 - val_loss: 0.0397 - val_accuracy: 0.9922
# Epoch 88/130
# 17/17 [==============================] - 104s 6s/step - loss: 0.0761 - accuracy: 0.9785 - val_loss: 0.0441 - val_accuracy: 0.9912
# Epoch 89/130
# 17/17 [==============================] - 109s 6s/step - loss: 0.0766 - accuracy: 0.9768 - val_loss: 0.0445 - val_accuracy: 0.9912
# Epoch 90/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0731 - accuracy: 0.9763 - val_loss: 0.0420 - val_accuracy: 0.9893
# Epoch 91/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0721 - accuracy: 0.9778 - val_loss: 0.0397 - val_accuracy: 0.9912
# Epoch 92/130
# 17/17 [==============================] - 104s 6s/step - loss: 0.0744 - accuracy: 0.9739 - val_loss: 0.0368 - val_accuracy: 0.9912
# Epoch 93/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.0724 - accuracy: 0.9790 - val_loss: 0.0438 - val_accuracy: 0.9883
# Epoch 94/130
# 17/17 [==============================] - 109s 6s/step - loss: 0.0695 - accuracy: 0.9797 - val_loss: 0.0364 - val_accuracy: 0.9902
# Epoch 95/130
# 17/17 [==============================] - 104s 6s/step - loss: 0.0643 - accuracy: 0.9807 - val_loss: 0.0396 - val_accuracy: 0.9883
# Epoch 96/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.0654 - accuracy: 0.9810 - val_loss: 0.0308 - val_accuracy: 0.9912
# Epoch 97/130
# 17/17 [==============================] - 107s 6s/step - loss: 0.0695 - accuracy: 0.9778 - val_loss: 0.0545 - val_accuracy: 0.9902
# Epoch 98/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.1776 - accuracy: 0.9380 - val_loss: 0.0949 - val_accuracy: 0.9795
# Epoch 99/130
# 17/17 [==============================] - 109s 6s/step - loss: 0.1441 - accuracy: 0.9500 - val_loss: 0.0459 - val_accuracy: 0.9902
# Epoch 100/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.1025 - accuracy: 0.9636 - val_loss: 0.0452 - val_accuracy: 0.9902
# Epoch 101/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0817 - accuracy: 0.9736 - val_loss: 0.0463 - val_accuracy: 0.9912
# Epoch 102/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0836 - accuracy: 0.9751 - val_loss: 0.0407 - val_accuracy: 0.9912
# Epoch 103/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.1080 - accuracy: 0.9624 - val_loss: 0.0450 - val_accuracy: 0.9893
# Epoch 104/130
# 17/17 [==============================] - 108s 6s/step - loss: 0.0936 - accuracy: 0.9666 - val_loss: 0.0444 - val_accuracy: 0.9902
# Epoch 105/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.0797 - accuracy: 0.9751 - val_loss: 0.0378 - val_accuracy: 0.9893
# Epoch 106/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0655 - accuracy: 0.9795 - val_loss: 0.0377 - val_accuracy: 0.9912
# Epoch 107/130
# 17/17 [==============================] - 102s 6s/step - loss: 0.0669 - accuracy: 0.9756 - val_loss: 0.0323 - val_accuracy: 0.9922
# Epoch 108/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.0594 - accuracy: 0.9827 - val_loss: 0.0290 - val_accuracy: 0.9922
# Epoch 109/130
# 17/17 [==============================] - 104s 6s/step - loss: 0.0606 - accuracy: 0.9797 - val_loss: 0.0307 - val_accuracy: 0.9912
# Epoch 110/130
# 17/17 [==============================] - 105s 6s/step - loss: 0.0503 - accuracy: 0.9824 - val_loss: 0.0301 - val_accuracy: 0.9902
# Epoch 111/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0541 - accuracy: 0.9849 - val_loss: 0.0285 - val_accuracy: 0.9922
# Epoch 112/130
# 17/17 [==============================] - 104s 6s/step - loss: 0.0560 - accuracy: 0.9832 - val_loss: 0.0314 - val_accuracy: 0.9932
# Epoch 113/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0541 - accuracy: 0.9846 - val_loss: 0.0285 - val_accuracy: 0.9922
# Epoch 114/130
# 17/17 [==============================] - 112s 7s/step - loss: 0.0543 - accuracy: 0.9844 - val_loss: 0.0385 - val_accuracy: 0.9912
# Epoch 115/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.0546 - accuracy: 0.9810 - val_loss: 0.0307 - val_accuracy: 0.9922
# Epoch 116/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0577 - accuracy: 0.9844 - val_loss: 0.0285 - val_accuracy: 0.9902
# Epoch 117/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.0515 - accuracy: 0.9844 - val_loss: 0.0244 - val_accuracy: 0.9932
# Epoch 118/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0514 - accuracy: 0.9839 - val_loss: 0.0259 - val_accuracy: 0.9922
# Epoch 119/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0547 - accuracy: 0.9846 - val_loss: 0.0337 - val_accuracy: 0.9912
# Epoch 120/130
# 17/17 [==============================] - 101s 6s/step - loss: 0.0572 - accuracy: 0.9824 - val_loss: 0.0298 - val_accuracy: 0.9902
# Epoch 121/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0550 - accuracy: 0.9793 - val_loss: 0.0276 - val_accuracy: 0.9941
# Epoch 122/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0565 - accuracy: 0.9836 - val_loss: 0.0230 - val_accuracy: 0.9932
# Epoch 123/130
# 17/17 [==============================] - 99s 6s/step - loss: 0.0521 - accuracy: 0.9819 - val_loss: 0.0271 - val_accuracy: 0.9932
# Epoch 124/130
# 17/17 [==============================] - 110s 6s/step - loss: 0.0491 - accuracy: 0.9846 - val_loss: 0.0306 - val_accuracy: 0.9941
# Epoch 125/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0525 - accuracy: 0.9851 - val_loss: 0.0254 - val_accuracy: 0.9941
# Epoch 126/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0578 - accuracy: 0.9795 - val_loss: 0.0211 - val_accuracy: 0.9951
# Epoch 127/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0489 - accuracy: 0.9849 - val_loss: 0.0294 - val_accuracy: 0.9912
# Epoch 128/130
# 17/17 [==============================] - 103s 6s/step - loss: 0.0533 - accuracy: 0.9829 - val_loss: 0.0227 - val_accuracy: 0.9941
# Epoch 129/130
# 17/17 [==============================] - 100s 6s/step - loss: 0.0490 - accuracy: 0.9856 - val_loss: 0.0278 - val_accuracy: 0.9932
# Epoch 130/130
# 17/17 [==============================] - 108s 6s/step - loss: 0.0523 - accuracy: 0.9824 - val_loss: 0.0250 - val_accuracy: 0.9941

# %%
# save the model
cnn.save('cnn.h5')

# %% [markdown]
# # Visualization

# %%
#visualization of the model evaluation
#plot image will change with more epochs
accuracy = cnn_history.history['accuracy']
val_accuracy = cnn_history.history['val_accuracy']
loss = cnn_history.history['loss']
val_loss = cnn_history.history['val_loss']
epochs = range(len(accuracy))

#Visualize the accuracy
plt.plot(epochs, accuracy, 'b', c = 'blue', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'b', c = 'orange', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.figure()

#Visualize the loss
plt.plot(epochs, loss, 'b', c = 'blue', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', c = 'orange', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluation

# %%
test_eval = cnn.evaluate(test_set, verbose = 0)

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])

# %% [markdown]
# # Classification Report

# %%
pred_classes = cnn.predict(test_set)

# %%
pred_classes = np.argmax(np.round(pred_classes), axis = 1)

# %%
#create a classification report
target_names = ['Class {}'.format(i) for i in range(4)]
print(classification_report(test_labels, pred_classes, target_names = target_names))

# %% [markdown]
# # Confusion Matrix

# %%
# create confusion matrix
cm = confusion_matrix(test_labels, pred_classes)

# %%
# create a heatmap
plt.figure(figsize=(9, 9))

sns.heatmap(cm, 
            annot = True, 
            fmt = ".2f",
            square = True,
            yticklabels = class_names, 
            xticklabels = class_names)
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
all_sample_title = f'Model Accuracy Score: {test_eval[1]:.2%}'
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Model Accuracy Score: 58.87%')
# Text(0.5, 1.0, 'Model Accuracy Score: 58.87%')
