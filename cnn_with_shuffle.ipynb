# %% [markdown]
# <a href="https://colab.research.google.com/github/KnzMcn/Attempts-At-Learning-CNN/blob/main/cnn_with_shuffle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from google.colab import drive
import zipfile
import os
from PIL import Image

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, Rescaling, Input
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Import the dataset

# %%
# mount google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# unzip the dataset file
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/3rd year/Machine Learning/Learning Evidence/Alzheimers.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# generate the image datasets
train_set = image_dataset_from_directory('/content/Alzheimers/train',
                                         label_mode = 'int',
                                         color_mode = 'grayscale',
                                         batch_size = 256, 
                                         image_size = (50, 50),  
                                         validation_split = 0.2,                                                                    
                                         subset = 'training',
                                         seed = 0,
                                         shuffle = True)

val_set = image_dataset_from_directory('/content/Alzheimers/train',
                                       label_mode = 'int',
                                       color_mode = 'grayscale',
                                       batch_size = 256,
                                       image_size = (50, 50),
                                       validation_split = 0.2,
                                       subset = 'validation',
                                       seed = 0,
                                       shuffle = True)

test_set = image_dataset_from_directory('/content/Alzheimers/test',
                                        label_mode = 'int',
                                        color_mode = 'grayscale',
                                        batch_size = 1279, 
                                        image_size = (50, 50), 
                                        shuffle = True)
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.
# Found 1279 files belonging to 4 classes.

# %%
# get the class names
class_names = train_set.class_names
class_names
# Out:
# ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
# display the images
plt.figure(figsize = (10, 10))
for images, labels in train_set.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(images[i].numpy().astype('float32').reshape(50, 50))
    plt.title(class_names[labels[i]])
    plt.axis('off')

# %%
# retrive the batches and labels of the train and test set
for batch, labels in train_set:
  print("Train set shape:", batch.shape, labels.shape)
  break

for batch, labels in test_set:
  test_labels = labels
  print("Test set shape:", batch.shape, test_labels.shape)
  break
# Out:
# Train set shape: (256, 50, 50, 1) (256,)
# Test set shape: (1279, 50, 50, 1) (1279,)

# %% [markdown]
# # Preprocessing

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_set = train_set.cache().prefetch(buffer_size = AUTOTUNE)
test_set = test_set.cache().prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# # Convolutional Neural Network

# %%
# state the number of classes and input shape
num_classes = 4
input_img = (50, 50, 1)

# %%
# build the network
cnn = Sequential([Input(shape = input_img), 
                  Rescaling(1./255),             

                  Conv2D(256, kernel_size = 3, activation = 'relu', padding = 'same'),
                  MaxPooling2D(2),
                  Dropout(0.75),

                  Flatten(),
                  Dense(128, activation = 'relu'),
                  Dropout(0.50),
                  Dense(num_classes, activation = 'softmax')])

# %%
# compile the network
cnn.compile(loss = 'sparse_categorical_crossentropy',
            optimizer = 'adam',
            metrics = ['accuracy'])
cnn.build(input_img)

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 50, 50, 1)         0
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 256)       2560
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 256)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 25, 25, 256)       0
#
#  flatten_1 (Flatten)         (None, 160000)            0
#
#  dense_2 (Dense)             (None, 128)               20480128
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 20,483,204
# Trainable params: 20,483,204
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model using the Generator

# %%
cnn_history = cnn.fit(train_set,
                      epochs = 130, 
                      verbose = 1,
                      validation_data = val_set)
# Out:
# Epoch 1/130
# 17/17 [==============================] - 50s 3s/step - loss: 1.8178 - accuracy: 0.4406 - val_loss: 1.0721 - val_accuracy: 0.5020
# Epoch 2/130
# 17/17 [==============================] - 46s 3s/step - loss: 1.0642 - accuracy: 0.4640 - val_loss: 1.0322 - val_accuracy: 0.5020
# Epoch 3/130
# 17/17 [==============================] - 50s 3s/step - loss: 1.0492 - accuracy: 0.4782 - val_loss: 1.0278 - val_accuracy: 0.5020
# Epoch 4/130
# 17/17 [==============================] - 45s 3s/step - loss: 1.0449 - accuracy: 0.4811 - val_loss: 1.0199 - val_accuracy: 0.5020
# Epoch 5/130
# 17/17 [==============================] - 48s 3s/step - loss: 1.0359 - accuracy: 0.4965 - val_loss: 1.0112 - val_accuracy: 0.5107
# Epoch 6/130
# 17/17 [==============================] - 51s 3s/step - loss: 1.0279 - accuracy: 0.4987 - val_loss: 1.0001 - val_accuracy: 0.5234
# Epoch 7/130
# 17/17 [==============================] - 47s 3s/step - loss: 1.0030 - accuracy: 0.5131 - val_loss: 0.9860 - val_accuracy: 0.5625
# Epoch 8/130
# 17/17 [==============================] - 47s 3s/step - loss: 0.9835 - accuracy: 0.5236 - val_loss: 0.9535 - val_accuracy: 0.5605
# Epoch 9/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.9610 - accuracy: 0.5392 - val_loss: 0.9317 - val_accuracy: 0.5537
# Epoch 10/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.9496 - accuracy: 0.5399 - val_loss: 0.9480 - val_accuracy: 0.5586
# Epoch 11/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.9453 - accuracy: 0.5294 - val_loss: 0.9106 - val_accuracy: 0.5752
# Epoch 12/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.9202 - accuracy: 0.5646 - val_loss: 0.8874 - val_accuracy: 0.5664
# Epoch 13/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.8996 - accuracy: 0.5614 - val_loss: 0.8809 - val_accuracy: 0.5771
# Epoch 14/130
# 17/17 [==============================] - 60s 4s/step - loss: 0.8899 - accuracy: 0.5670 - val_loss: 0.8931 - val_accuracy: 0.5664
# Epoch 15/130
# 17/17 [==============================] - 57s 3s/step - loss: 0.8950 - accuracy: 0.5643 - val_loss: 0.8599 - val_accuracy: 0.5918
# Epoch 16/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.8726 - accuracy: 0.5777 - val_loss: 0.8537 - val_accuracy: 0.5752
# Epoch 17/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.8572 - accuracy: 0.5863 - val_loss: 0.8323 - val_accuracy: 0.5918
# Epoch 18/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.8372 - accuracy: 0.5897 - val_loss: 0.8128 - val_accuracy: 0.5928
# Epoch 19/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.8351 - accuracy: 0.5997 - val_loss: 0.8023 - val_accuracy: 0.5938
# Epoch 20/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.8011 - accuracy: 0.6229 - val_loss: 0.7870 - val_accuracy: 0.6074
# Epoch 21/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.7765 - accuracy: 0.6327 - val_loss: 0.7543 - val_accuracy: 0.6318
# Epoch 22/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.7499 - accuracy: 0.6483 - val_loss: 0.7502 - val_accuracy: 0.6279
# Epoch 23/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.7442 - accuracy: 0.6446 - val_loss: 0.7401 - val_accuracy: 0.6338
# Epoch 24/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.7286 - accuracy: 0.6617 - val_loss: 0.7068 - val_accuracy: 0.7158
# Epoch 25/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.7052 - accuracy: 0.6817 - val_loss: 0.6763 - val_accuracy: 0.7168
# Epoch 26/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.6754 - accuracy: 0.6927 - val_loss: 0.6554 - val_accuracy: 0.7148
# Epoch 27/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.6682 - accuracy: 0.6973 - val_loss: 0.6495 - val_accuracy: 0.7637
# Epoch 28/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.6410 - accuracy: 0.7159 - val_loss: 0.6224 - val_accuracy: 0.7646
# Epoch 29/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.6288 - accuracy: 0.7330 - val_loss: 0.5967 - val_accuracy: 0.7578
# Epoch 30/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.6142 - accuracy: 0.7344 - val_loss: 0.5821 - val_accuracy: 0.7822
# Epoch 31/130
# 17/17 [==============================] - 62s 4s/step - loss: 0.5997 - accuracy: 0.7403 - val_loss: 0.5532 - val_accuracy: 0.7979
# Epoch 32/130
# 17/17 [==============================] - 59s 3s/step - loss: 0.5920 - accuracy: 0.7423 - val_loss: 0.5327 - val_accuracy: 0.8037
# Epoch 33/130
# 17/17 [==============================] - 61s 4s/step - loss: 0.5622 - accuracy: 0.7562 - val_loss: 0.5215 - val_accuracy: 0.8369
# Epoch 34/130
# 17/17 [==============================] - 63s 4s/step - loss: 0.5422 - accuracy: 0.7742 - val_loss: 0.5034 - val_accuracy: 0.8477
# Epoch 35/130
# 17/17 [==============================] - 55s 3s/step - loss: 0.5098 - accuracy: 0.7918 - val_loss: 0.4711 - val_accuracy: 0.8477
# Epoch 36/130
# 17/17 [==============================] - 55s 3s/step - loss: 0.5091 - accuracy: 0.7913 - val_loss: 0.4634 - val_accuracy: 0.8535
# Epoch 37/130
# 17/17 [==============================] - 56s 3s/step - loss: 0.4741 - accuracy: 0.8165 - val_loss: 0.4415 - val_accuracy: 0.8672
# Epoch 38/130
# 17/17 [==============================] - 59s 4s/step - loss: 0.4647 - accuracy: 0.8111 - val_loss: 0.4268 - val_accuracy: 0.8672
# Epoch 39/130
# 17/17 [==============================] - 61s 4s/step - loss: 0.4537 - accuracy: 0.8118 - val_loss: 0.4094 - val_accuracy: 0.8760
# Epoch 40/130
# 17/17 [==============================] - 64s 4s/step - loss: 0.4419 - accuracy: 0.8252 - val_loss: 0.4002 - val_accuracy: 0.8789
# Epoch 41/130
# 17/17 [==============================] - 58s 3s/step - loss: 0.4275 - accuracy: 0.8284 - val_loss: 0.3816 - val_accuracy: 0.8887
# Epoch 42/130
# 17/17 [==============================] - 57s 3s/step - loss: 0.4168 - accuracy: 0.8384 - val_loss: 0.3542 - val_accuracy: 0.8887
# Epoch 43/130
# 17/17 [==============================] - 58s 3s/step - loss: 0.3974 - accuracy: 0.8401 - val_loss: 0.3452 - val_accuracy: 0.8965
# Epoch 44/130
# 17/17 [==============================] - 62s 4s/step - loss: 0.4012 - accuracy: 0.8382 - val_loss: 0.3995 - val_accuracy: 0.8574
# Epoch 45/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.3894 - accuracy: 0.8460 - val_loss: 0.3535 - val_accuracy: 0.8896
# Epoch 46/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.3745 - accuracy: 0.8536 - val_loss: 0.3218 - val_accuracy: 0.9033
# Epoch 47/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.3648 - accuracy: 0.8579 - val_loss: 0.2945 - val_accuracy: 0.9170
# Epoch 48/130
# 17/17 [==============================] - 62s 4s/step - loss: 0.3541 - accuracy: 0.8619 - val_loss: 0.2893 - val_accuracy: 0.9219
# Epoch 49/130
# 17/17 [==============================] - 57s 3s/step - loss: 0.3462 - accuracy: 0.8680 - val_loss: 0.2853 - val_accuracy: 0.9219
# Epoch 50/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.3411 - accuracy: 0.8599 - val_loss: 0.2759 - val_accuracy: 0.9160
# Epoch 51/130
# 17/17 [==============================] - 59s 3s/step - loss: 0.3244 - accuracy: 0.8743 - val_loss: 0.2613 - val_accuracy: 0.9277
# Epoch 52/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3134 - accuracy: 0.8758 - val_loss: 0.2697 - val_accuracy: 0.9102
# Epoch 53/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3124 - accuracy: 0.8814 - val_loss: 0.2502 - val_accuracy: 0.9219
# Epoch 54/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2896 - accuracy: 0.8931 - val_loss: 0.2640 - val_accuracy: 0.9053
# Epoch 55/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2959 - accuracy: 0.8892 - val_loss: 0.2503 - val_accuracy: 0.9160
# Epoch 56/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3096 - accuracy: 0.8767 - val_loss: 0.2301 - val_accuracy: 0.9395
# Epoch 57/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2883 - accuracy: 0.8848 - val_loss: 0.2459 - val_accuracy: 0.9141
# Epoch 58/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.2741 - accuracy: 0.8919 - val_loss: 0.2572 - val_accuracy: 0.9033
# Epoch 59/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2633 - accuracy: 0.8950 - val_loss: 0.2190 - val_accuracy: 0.9355
# Epoch 60/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2663 - accuracy: 0.8960 - val_loss: 0.2291 - val_accuracy: 0.9219
# Epoch 61/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.2675 - accuracy: 0.8958 - val_loss: 0.2071 - val_accuracy: 0.9346
# Epoch 62/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2576 - accuracy: 0.9026 - val_loss: 0.1924 - val_accuracy: 0.9541
# Epoch 63/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2490 - accuracy: 0.9077 - val_loss: 0.2226 - val_accuracy: 0.9316
# Epoch 64/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3245 - accuracy: 0.8677 - val_loss: 0.2214 - val_accuracy: 0.9434
# Epoch 65/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3093 - accuracy: 0.8726 - val_loss: 0.2135 - val_accuracy: 0.9414
# Epoch 66/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2649 - accuracy: 0.8955 - val_loss: 0.1875 - val_accuracy: 0.9502
# Epoch 67/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2537 - accuracy: 0.9031 - val_loss: 0.1722 - val_accuracy: 0.9580
# Epoch 68/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2316 - accuracy: 0.9121 - val_loss: 0.1739 - val_accuracy: 0.9531
# Epoch 69/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.2292 - accuracy: 0.9097 - val_loss: 0.1622 - val_accuracy: 0.9531
# Epoch 70/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2222 - accuracy: 0.9187 - val_loss: 0.1594 - val_accuracy: 0.9561
# Epoch 71/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2172 - accuracy: 0.9173 - val_loss: 0.1638 - val_accuracy: 0.9482
# Epoch 72/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.2155 - accuracy: 0.9173 - val_loss: 0.1606 - val_accuracy: 0.9492
# Epoch 73/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2111 - accuracy: 0.9126 - val_loss: 0.1429 - val_accuracy: 0.9648
# Epoch 74/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1994 - accuracy: 0.9216 - val_loss: 0.1471 - val_accuracy: 0.9609
# Epoch 75/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2039 - accuracy: 0.9297 - val_loss: 0.1646 - val_accuracy: 0.9512
# Epoch 76/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2984 - accuracy: 0.8845 - val_loss: 0.1789 - val_accuracy: 0.9609
# Epoch 77/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2407 - accuracy: 0.9121 - val_loss: 0.1534 - val_accuracy: 0.9639
# Epoch 78/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2129 - accuracy: 0.9207 - val_loss: 0.1420 - val_accuracy: 0.9629
# Epoch 79/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.2012 - accuracy: 0.9319 - val_loss: 0.1360 - val_accuracy: 0.9648
# Epoch 80/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1976 - accuracy: 0.9280 - val_loss: 0.1320 - val_accuracy: 0.9668
# Epoch 81/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1905 - accuracy: 0.9317 - val_loss: 0.1222 - val_accuracy: 0.9736
# Epoch 82/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1742 - accuracy: 0.9392 - val_loss: 0.1227 - val_accuracy: 0.9717
# Epoch 83/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1774 - accuracy: 0.9348 - val_loss: 0.1219 - val_accuracy: 0.9717
# Epoch 84/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1791 - accuracy: 0.9380 - val_loss: 0.1183 - val_accuracy: 0.9756
# Epoch 85/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1624 - accuracy: 0.9448 - val_loss: 0.1100 - val_accuracy: 0.9766
# Epoch 86/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1705 - accuracy: 0.9407 - val_loss: 0.1128 - val_accuracy: 0.9766
# Epoch 87/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1591 - accuracy: 0.9417 - val_loss: 0.1140 - val_accuracy: 0.9697
# Epoch 88/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1683 - accuracy: 0.9412 - val_loss: 0.1086 - val_accuracy: 0.9756
# Epoch 89/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1598 - accuracy: 0.9407 - val_loss: 0.1097 - val_accuracy: 0.9766
# Epoch 90/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1630 - accuracy: 0.9407 - val_loss: 0.1087 - val_accuracy: 0.9756
# Epoch 91/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1684 - accuracy: 0.9412 - val_loss: 0.1081 - val_accuracy: 0.9766
# Epoch 92/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1513 - accuracy: 0.9514 - val_loss: 0.1055 - val_accuracy: 0.9766
# Epoch 93/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.1869 - accuracy: 0.9290 - val_loss: 0.1107 - val_accuracy: 0.9756
# Epoch 94/130
# 17/17 [==============================] - 57s 3s/step - loss: 0.1632 - accuracy: 0.9390 - val_loss: 0.1097 - val_accuracy: 0.9746
# Epoch 95/130
# 17/17 [==============================] - 55s 3s/step - loss: 0.1639 - accuracy: 0.9426 - val_loss: 0.1081 - val_accuracy: 0.9736
# Epoch 96/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1554 - accuracy: 0.9424 - val_loss: 0.1070 - val_accuracy: 0.9736
# Epoch 97/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1531 - accuracy: 0.9458 - val_loss: 0.1052 - val_accuracy: 0.9775
# Epoch 98/130
# 17/17 [==============================] - 55s 3s/step - loss: 0.1575 - accuracy: 0.9490 - val_loss: 0.0939 - val_accuracy: 0.9756
# Epoch 99/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1400 - accuracy: 0.9505 - val_loss: 0.0937 - val_accuracy: 0.9775
# Epoch 100/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1494 - accuracy: 0.9465 - val_loss: 0.0885 - val_accuracy: 0.9746
# Epoch 101/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1557 - accuracy: 0.9458 - val_loss: 0.1006 - val_accuracy: 0.9746
# Epoch 102/130
# 17/17 [==============================] - 58s 3s/step - loss: 0.1433 - accuracy: 0.9473 - val_loss: 0.0912 - val_accuracy: 0.9775
# Epoch 103/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1515 - accuracy: 0.9478 - val_loss: 0.0909 - val_accuracy: 0.9795
# Epoch 104/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.1444 - accuracy: 0.9446 - val_loss: 0.0976 - val_accuracy: 0.9795
# Epoch 105/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.1574 - accuracy: 0.9485 - val_loss: 0.0891 - val_accuracy: 0.9775
# Epoch 106/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.1438 - accuracy: 0.9522 - val_loss: 0.0963 - val_accuracy: 0.9766
# Epoch 107/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1352 - accuracy: 0.9524 - val_loss: 0.0855 - val_accuracy: 0.9775
# Epoch 108/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.1576 - accuracy: 0.9429 - val_loss: 0.0928 - val_accuracy: 0.9775
# Epoch 109/130
# 17/17 [==============================] - 58s 3s/step - loss: 0.1416 - accuracy: 0.9470 - val_loss: 0.0856 - val_accuracy: 0.9795
# Epoch 110/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1431 - accuracy: 0.9517 - val_loss: 0.0831 - val_accuracy: 0.9824
# Epoch 111/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.1344 - accuracy: 0.9497 - val_loss: 0.0849 - val_accuracy: 0.9834
# Epoch 112/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1357 - accuracy: 0.9514 - val_loss: 0.0836 - val_accuracy: 0.9814
# Epoch 113/130
# 17/17 [==============================] - 55s 3s/step - loss: 0.1348 - accuracy: 0.9517 - val_loss: 0.0814 - val_accuracy: 0.9795
# Epoch 114/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1394 - accuracy: 0.9485 - val_loss: 0.0795 - val_accuracy: 0.9795
# Epoch 115/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.1425 - accuracy: 0.9461 - val_loss: 0.0837 - val_accuracy: 0.9805
# Epoch 116/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.1329 - accuracy: 0.9517 - val_loss: 0.0767 - val_accuracy: 0.9814
# Epoch 117/130
# 17/17 [==============================] - 53s 3s/step - loss: 0.1226 - accuracy: 0.9563 - val_loss: 0.0819 - val_accuracy: 0.9756
# Epoch 118/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.1227 - accuracy: 0.9590 - val_loss: 0.0762 - val_accuracy: 0.9824
# Epoch 119/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.1336 - accuracy: 0.9546 - val_loss: 0.0788 - val_accuracy: 0.9795
# Epoch 120/130
# 17/17 [==============================] - 57s 3s/step - loss: 0.1282 - accuracy: 0.9536 - val_loss: 0.0868 - val_accuracy: 0.9795
# Epoch 121/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.1317 - accuracy: 0.9534 - val_loss: 0.0733 - val_accuracy: 0.9814
# Epoch 122/130
# 17/17 [==============================] - 57s 3s/step - loss: 0.1155 - accuracy: 0.9631 - val_loss: 0.0854 - val_accuracy: 0.9766
# Epoch 123/130
# 17/17 [==============================] - 54s 3s/step - loss: 0.3791 - accuracy: 0.8440 - val_loss: 0.1881 - val_accuracy: 0.9424
# Epoch 124/130
# 17/17 [==============================] - 55s 3s/step - loss: 0.3629 - accuracy: 0.8409 - val_loss: 0.1374 - val_accuracy: 0.9795
# Epoch 125/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2234 - accuracy: 0.9177 - val_loss: 0.1024 - val_accuracy: 0.9795
# Epoch 126/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.1917 - accuracy: 0.9290 - val_loss: 0.0928 - val_accuracy: 0.9756
# Epoch 127/130
# 17/17 [==============================] - 58s 3s/step - loss: 0.1768 - accuracy: 0.9329 - val_loss: 0.0815 - val_accuracy: 0.9795
# Epoch 128/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1525 - accuracy: 0.9419 - val_loss: 0.0890 - val_accuracy: 0.9727
# Epoch 129/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1601 - accuracy: 0.9400 - val_loss: 0.0821 - val_accuracy: 0.9824
# Epoch 130/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1468 - accuracy: 0.9456 - val_loss: 0.0810 - val_accuracy: 0.9814

# %%
# save the model
cnn.save('cnn.h5')

# %% [markdown]
# # Visualization

# %%
#visualization of the model evaluation
#plot image will change with more epochs
accuracy = cnn_history.history['accuracy']
val_accuracy = cnn_history.history['val_accuracy']
loss = cnn_history.history['loss']
val_loss = cnn_history.history['val_loss']
epochs = range(len(accuracy))

#Visualize the accuracy
plt.plot(epochs, accuracy, 'b', c = 'blue', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'b', c = 'orange', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.figure()

#Visualize the loss
plt.plot(epochs, loss, 'b', c = 'blue', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', c = 'orange', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluation

# %%
test_eval = cnn.evaluate(test_set, verbose = 0)

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 1.44784414768219
# Test accuracy: 0.6215793490409851

# %% [markdown]
# # Classification Report

# %%
pred_classes = cnn.predict(test_set)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
pred_classes = np.argmax(np.round(pred_classes), axis = 1)

# %%
#create a classification report
target_names = ['Class {}'.format(i) for i in range(4)]
print(classification_report(test_labels, pred_classes, target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.18      0.08      0.11       179
#      Class 1       0.00      0.00      0.00        12
#      Class 2       0.50      0.40      0.45       640
#      Class 3       0.36      0.56      0.44       448
#
#     accuracy                           0.41      1279
#    macro avg       0.26      0.26      0.25      1279
# weighted avg       0.40      0.41      0.39      1279
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Confusion Matrix

# %%
# create confusion matrix
cm = confusion_matrix(test_labels, pred_classes)

# %%
# create a heatmap
plt.figure(figsize=(9, 9))

sns.heatmap(cm, 
            annot = True, 
            fmt = ".2f",
            square = True,
            yticklabels = class_names, 
            xticklabels = class_names)
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
all_sample_title = f'Model Accuracy Score: {test_eval[1]:.2%}'
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Model Accuracy Score: 62.16%')
