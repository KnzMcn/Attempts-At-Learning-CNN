# %% [markdown]
# <a href="https://colab.research.google.com/github/KnzMcn/Attempts-At-Learning-CNN/blob/main/cnn_with_shuffle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from google.colab import drive
import zipfile
import os
from PIL import Image

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, Rescaling, Input
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Import the dataset

# %%
# mount google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# unzip the dataset file
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/3rd year/Machine Learning/Learning Evidence/Alzheimers.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# generate the image datasets
train_set = image_dataset_from_directory('/content/Alzheimers/train',
                                         label_mode = 'int',
                                         color_mode = 'grayscale',
                                         batch_size = 256, 
                                         image_size = (100, 100),  
                                         validation_split = 0.2,                                                                    
                                         subset = 'training',
                                         seed = 0,
                                         shuffle = True)

val_set = image_dataset_from_directory('/content/Alzheimers/train',
                                       label_mode = 'int',
                                       color_mode = 'grayscale',
                                       batch_size = 256,
                                       image_size = (100, 100),
                                       validation_split = 0.2,
                                       subset = 'validation',
                                       seed = 0,
                                       shuffle = True)

test_set = image_dataset_from_directory('/content/Alzheimers/test',
                                        label_mode = 'int',
                                        color_mode = 'grayscale',
                                        batch_size = 1279, 
                                        image_size = (100, 100), 
                                        shuffle = True)
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.
# Found 1279 files belonging to 4 classes.

# %%
# get the class names
class_names = train_set.class_names
class_names
# Out:
# ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
# display the images
plt.figure(figsize = (10, 10))
for images, labels in train_set.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(images[i].numpy().astype('float32').reshape(100, 100))
    plt.title(class_names[labels[i]])
    plt.axis('off')

# %%
# retrive the batches and labels of the train and test set
for batch, labels in train_set:
  print("Train set shape:", batch.shape, labels.shape)
  break

for batch, labels in test_set:
  test_labels = labels
  print("Test set shape:", batch.shape, test_labels.shape)
  break
# Out:
# Train set shape: (256, 100, 100, 1) (256,)
# Test set shape: (1279, 100, 100, 1) (1279,)

# %% [markdown]
# # Preprocessing

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_set = train_set.cache().prefetch(buffer_size = AUTOTUNE)
test_set = test_set.cache().prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# # Convolutional Neural Network

# %%
# state the number of classes and input shape
num_classes = 4
input_img = (100, 100, 1)

# %%
# build the network
cnn = Sequential([Input(shape = input_img), 
                  Rescaling(1./255),             

                  Conv2D(64, kernel_size = 3, activation = 'relu', padding = 'same'),
                  MaxPooling2D(2),
                  Dropout(0.75),

                  Flatten(),
                  Dense(128, activation = 'relu'),
                  Dropout(0.50),
                  Dense(num_classes, activation = 'softmax')])

# %%
# compile the network
cnn.compile(loss = 'sparse_categorical_crossentropy',
            optimizer = 'adam',
            metrics = ['accuracy'])
cnn.build(input_img)

# %%
cnn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 100, 100, 1)       0
#
#  conv2d_4 (Conv2D)           (None, 100, 100, 64)      640
#
#  max_pooling2d_4 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 50, 50, 64)        0
#
#  flatten_4 (Flatten)         (None, 160000)            0
#
#  dense_8 (Dense)             (None, 128)               20480128
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 20,481,284
# Trainable params: 20,481,284
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model using the Generator

# %%
cnn_history = cnn.fit(train_set,
                      epochs = 130, 
                      verbose = 1,
                      validation_data = val_set)
# Out:
# Epoch 1/130
# 17/17 [==============================] - 50s 3s/step - loss: 3.4182 - accuracy: 0.4113 - val_loss: 1.1005 - val_accuracy: 0.5020
# Epoch 2/130
# 17/17 [==============================] - 48s 3s/step - loss: 1.0789 - accuracy: 0.5001 - val_loss: 1.0140 - val_accuracy: 0.5020
# Epoch 3/130
# 17/17 [==============================] - 50s 3s/step - loss: 1.0497 - accuracy: 0.4860 - val_loss: 1.0015 - val_accuracy: 0.5020
# Epoch 4/130
# 17/17 [==============================] - 48s 3s/step - loss: 1.0437 - accuracy: 0.4862 - val_loss: 0.9955 - val_accuracy: 0.5029
# Epoch 5/130
# 17/17 [==============================] - 48s 3s/step - loss: 1.0309 - accuracy: 0.4933 - val_loss: 0.9863 - val_accuracy: 0.5049
# Epoch 6/130
# 17/17 [==============================] - 48s 3s/step - loss: 1.0209 - accuracy: 0.4950 - val_loss: 0.9758 - val_accuracy: 0.5107
# Epoch 7/130
# 17/17 [==============================] - 48s 3s/step - loss: 1.0150 - accuracy: 0.4869 - val_loss: 0.9683 - val_accuracy: 0.5371
# Epoch 8/130
# 17/17 [==============================] - 48s 3s/step - loss: 1.0092 - accuracy: 0.5004 - val_loss: 0.9582 - val_accuracy: 0.5186
# Epoch 9/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.9934 - accuracy: 0.5048 - val_loss: 0.9436 - val_accuracy: 0.5205
# Epoch 10/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.9747 - accuracy: 0.5182 - val_loss: 0.9281 - val_accuracy: 0.5488
# Epoch 11/130
# 17/17 [==============================] - 48s 3s/step - loss: 0.9542 - accuracy: 0.5328 - val_loss: 0.9193 - val_accuracy: 0.5732
# Epoch 12/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.9353 - accuracy: 0.5450 - val_loss: 0.9280 - val_accuracy: 0.5693
# Epoch 13/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.9393 - accuracy: 0.5426 - val_loss: 0.8915 - val_accuracy: 0.5732
# Epoch 14/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.9211 - accuracy: 0.5492 - val_loss: 0.8785 - val_accuracy: 0.5869
# Epoch 15/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.8928 - accuracy: 0.5531 - val_loss: 0.8683 - val_accuracy: 0.5898
# Epoch 16/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.8838 - accuracy: 0.5716 - val_loss: 0.8424 - val_accuracy: 0.6074
# Epoch 17/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.8539 - accuracy: 0.5873 - val_loss: 0.8186 - val_accuracy: 0.6143
# Epoch 18/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.8301 - accuracy: 0.5958 - val_loss: 0.8059 - val_accuracy: 0.6260
# Epoch 19/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.8010 - accuracy: 0.6146 - val_loss: 0.7684 - val_accuracy: 0.6270
# Epoch 20/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.7869 - accuracy: 0.6266 - val_loss: 0.7404 - val_accuracy: 0.6689
# Epoch 21/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.7604 - accuracy: 0.6390 - val_loss: 0.7328 - val_accuracy: 0.6699
# Epoch 22/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.7441 - accuracy: 0.6473 - val_loss: 0.7418 - val_accuracy: 0.7207
# Epoch 23/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.7364 - accuracy: 0.6483 - val_loss: 0.6989 - val_accuracy: 0.6680
# Epoch 24/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.7105 - accuracy: 0.6678 - val_loss: 0.6483 - val_accuracy: 0.7129
# Epoch 25/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.6832 - accuracy: 0.6854 - val_loss: 0.6289 - val_accuracy: 0.7139
# Epoch 26/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.6574 - accuracy: 0.7027 - val_loss: 0.6243 - val_accuracy: 0.7246
# Epoch 27/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.6430 - accuracy: 0.7174 - val_loss: 0.5879 - val_accuracy: 0.7559
# Epoch 28/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.6241 - accuracy: 0.7335 - val_loss: 0.5751 - val_accuracy: 0.7568
# Epoch 29/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.6090 - accuracy: 0.7327 - val_loss: 0.5648 - val_accuracy: 0.7773
# Epoch 30/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.5849 - accuracy: 0.7493 - val_loss: 0.5149 - val_accuracy: 0.8076
# Epoch 31/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.5662 - accuracy: 0.7591 - val_loss: 0.5101 - val_accuracy: 0.8213
# Epoch 32/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.5492 - accuracy: 0.7659 - val_loss: 0.4926 - val_accuracy: 0.8047
# Epoch 33/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.5257 - accuracy: 0.7850 - val_loss: 0.4592 - val_accuracy: 0.8359
# Epoch 34/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.5235 - accuracy: 0.7808 - val_loss: 0.4586 - val_accuracy: 0.8389
# Epoch 35/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4999 - accuracy: 0.7974 - val_loss: 0.4636 - val_accuracy: 0.8311
# Epoch 36/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.5035 - accuracy: 0.7935 - val_loss: 0.4149 - val_accuracy: 0.8545
# Epoch 37/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4767 - accuracy: 0.8082 - val_loss: 0.3883 - val_accuracy: 0.8789
# Epoch 38/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4552 - accuracy: 0.8165 - val_loss: 0.3774 - val_accuracy: 0.8828
# Epoch 39/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.4406 - accuracy: 0.8245 - val_loss: 0.3622 - val_accuracy: 0.8877
# Epoch 40/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4298 - accuracy: 0.8294 - val_loss: 0.3567 - val_accuracy: 0.8799
# Epoch 41/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.4210 - accuracy: 0.8428 - val_loss: 0.3226 - val_accuracy: 0.9102
# Epoch 42/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4181 - accuracy: 0.8396 - val_loss: 0.3199 - val_accuracy: 0.9072
# Epoch 43/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4096 - accuracy: 0.8362 - val_loss: 0.3194 - val_accuracy: 0.9033
# Epoch 44/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.3949 - accuracy: 0.8389 - val_loss: 0.3133 - val_accuracy: 0.9141
# Epoch 45/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.4025 - accuracy: 0.8474 - val_loss: 0.2874 - val_accuracy: 0.9170
# Epoch 46/130
# 17/17 [==============================] - 52s 3s/step - loss: 0.3817 - accuracy: 0.8531 - val_loss: 0.2763 - val_accuracy: 0.9258
# Epoch 47/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.3747 - accuracy: 0.8560 - val_loss: 0.2678 - val_accuracy: 0.9277
# Epoch 48/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.3628 - accuracy: 0.8548 - val_loss: 0.2477 - val_accuracy: 0.9365
# Epoch 49/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3736 - accuracy: 0.8523 - val_loss: 0.2831 - val_accuracy: 0.9023
# Epoch 50/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3595 - accuracy: 0.8589 - val_loss: 0.2492 - val_accuracy: 0.9453
# Epoch 51/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.3423 - accuracy: 0.8665 - val_loss: 0.2535 - val_accuracy: 0.9443
# Epoch 52/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3616 - accuracy: 0.8565 - val_loss: 0.2463 - val_accuracy: 0.9434
# Epoch 53/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3356 - accuracy: 0.8655 - val_loss: 0.2309 - val_accuracy: 0.9355
# Epoch 54/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3408 - accuracy: 0.8572 - val_loss: 0.2238 - val_accuracy: 0.9434
# Epoch 55/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.3199 - accuracy: 0.8753 - val_loss: 0.2266 - val_accuracy: 0.9414
# Epoch 56/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3262 - accuracy: 0.8723 - val_loss: 0.2091 - val_accuracy: 0.9482
# Epoch 57/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.3083 - accuracy: 0.8809 - val_loss: 0.2073 - val_accuracy: 0.9531
# Epoch 58/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3094 - accuracy: 0.8797 - val_loss: 0.1942 - val_accuracy: 0.9482
# Epoch 59/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3000 - accuracy: 0.8843 - val_loss: 0.1841 - val_accuracy: 0.9482
# Epoch 60/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.3108 - accuracy: 0.8789 - val_loss: 0.1805 - val_accuracy: 0.9531
# Epoch 61/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.3012 - accuracy: 0.8877 - val_loss: 0.1879 - val_accuracy: 0.9492
# Epoch 62/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2906 - accuracy: 0.8843 - val_loss: 0.1874 - val_accuracy: 0.9580
# Epoch 63/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2892 - accuracy: 0.8880 - val_loss: 0.1709 - val_accuracy: 0.9590
# Epoch 64/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2854 - accuracy: 0.8902 - val_loss: 0.1717 - val_accuracy: 0.9629
# Epoch 65/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2756 - accuracy: 0.8975 - val_loss: 0.1595 - val_accuracy: 0.9648
# Epoch 66/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2777 - accuracy: 0.8948 - val_loss: 0.1596 - val_accuracy: 0.9580
# Epoch 67/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2782 - accuracy: 0.8968 - val_loss: 0.1506 - val_accuracy: 0.9531
# Epoch 68/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2677 - accuracy: 0.8955 - val_loss: 0.1463 - val_accuracy: 0.9639
# Epoch 69/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2564 - accuracy: 0.9019 - val_loss: 0.1485 - val_accuracy: 0.9648
# Epoch 70/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2707 - accuracy: 0.8975 - val_loss: 0.1521 - val_accuracy: 0.9561
# Epoch 71/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2638 - accuracy: 0.9002 - val_loss: 0.1432 - val_accuracy: 0.9707
# Epoch 72/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2630 - accuracy: 0.8992 - val_loss: 0.1537 - val_accuracy: 0.9639
# Epoch 73/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2570 - accuracy: 0.8960 - val_loss: 0.1340 - val_accuracy: 0.9727
# Epoch 74/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2548 - accuracy: 0.8994 - val_loss: 0.1430 - val_accuracy: 0.9668
# Epoch 75/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2557 - accuracy: 0.8980 - val_loss: 0.1619 - val_accuracy: 0.9492
# Epoch 76/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2566 - accuracy: 0.8938 - val_loss: 0.1281 - val_accuracy: 0.9688
# Epoch 77/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2454 - accuracy: 0.9036 - val_loss: 0.1197 - val_accuracy: 0.9697
# Epoch 78/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2398 - accuracy: 0.9068 - val_loss: 0.1187 - val_accuracy: 0.9707
# Epoch 79/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2613 - accuracy: 0.8938 - val_loss: 0.1312 - val_accuracy: 0.9580
# Epoch 80/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2481 - accuracy: 0.9058 - val_loss: 0.1192 - val_accuracy: 0.9707
# Epoch 81/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2307 - accuracy: 0.9092 - val_loss: 0.1173 - val_accuracy: 0.9707
# Epoch 82/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2318 - accuracy: 0.9129 - val_loss: 0.1237 - val_accuracy: 0.9707
# Epoch 83/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2426 - accuracy: 0.9070 - val_loss: 0.1352 - val_accuracy: 0.9658
# Epoch 84/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2598 - accuracy: 0.8870 - val_loss: 0.1115 - val_accuracy: 0.9736
# Epoch 85/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2429 - accuracy: 0.8977 - val_loss: 0.1166 - val_accuracy: 0.9736
# Epoch 86/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2360 - accuracy: 0.9033 - val_loss: 0.1104 - val_accuracy: 0.9775
# Epoch 87/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2350 - accuracy: 0.9063 - val_loss: 0.1071 - val_accuracy: 0.9736
# Epoch 88/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2324 - accuracy: 0.9031 - val_loss: 0.1095 - val_accuracy: 0.9697
# Epoch 89/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2267 - accuracy: 0.9053 - val_loss: 0.0980 - val_accuracy: 0.9756
# Epoch 90/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2172 - accuracy: 0.9158 - val_loss: 0.0986 - val_accuracy: 0.9756
# Epoch 91/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2277 - accuracy: 0.9131 - val_loss: 0.1002 - val_accuracy: 0.9756
# Epoch 92/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2241 - accuracy: 0.9160 - val_loss: 0.0911 - val_accuracy: 0.9775
# Epoch 93/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2215 - accuracy: 0.9141 - val_loss: 0.0940 - val_accuracy: 0.9736
# Epoch 94/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2362 - accuracy: 0.9082 - val_loss: 0.1014 - val_accuracy: 0.9746
# Epoch 95/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2070 - accuracy: 0.9224 - val_loss: 0.0880 - val_accuracy: 0.9756
# Epoch 96/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2205 - accuracy: 0.9092 - val_loss: 0.0923 - val_accuracy: 0.9766
# Epoch 97/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2124 - accuracy: 0.9185 - val_loss: 0.0884 - val_accuracy: 0.9775
# Epoch 98/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2106 - accuracy: 0.9204 - val_loss: 0.0982 - val_accuracy: 0.9766
# Epoch 99/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2218 - accuracy: 0.9134 - val_loss: 0.0893 - val_accuracy: 0.9746
# Epoch 100/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2126 - accuracy: 0.9146 - val_loss: 0.0849 - val_accuracy: 0.9775
# Epoch 101/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2134 - accuracy: 0.9141 - val_loss: 0.0848 - val_accuracy: 0.9766
# Epoch 102/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2050 - accuracy: 0.9221 - val_loss: 0.0803 - val_accuracy: 0.9795
# Epoch 103/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2095 - accuracy: 0.9192 - val_loss: 0.0801 - val_accuracy: 0.9775
# Epoch 104/130
# 17/17 [==============================] - 50s 3s/step - loss: 0.2049 - accuracy: 0.9209 - val_loss: 0.0813 - val_accuracy: 0.9805
# Epoch 105/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2045 - accuracy: 0.9251 - val_loss: 0.0835 - val_accuracy: 0.9795
# Epoch 106/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1964 - accuracy: 0.9231 - val_loss: 0.0851 - val_accuracy: 0.9746
# Epoch 107/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2110 - accuracy: 0.9146 - val_loss: 0.1038 - val_accuracy: 0.9736
# Epoch 108/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1948 - accuracy: 0.9258 - val_loss: 0.1040 - val_accuracy: 0.9717
# Epoch 109/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2049 - accuracy: 0.9190 - val_loss: 0.0814 - val_accuracy: 0.9766
# Epoch 110/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.2040 - accuracy: 0.9214 - val_loss: 0.0865 - val_accuracy: 0.9814
# Epoch 111/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.2010 - accuracy: 0.9207 - val_loss: 0.1031 - val_accuracy: 0.9756
# Epoch 112/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1970 - accuracy: 0.9195 - val_loss: 0.0795 - val_accuracy: 0.9805
# Epoch 113/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1996 - accuracy: 0.9216 - val_loss: 0.0768 - val_accuracy: 0.9785
# Epoch 114/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1929 - accuracy: 0.9246 - val_loss: 0.0716 - val_accuracy: 0.9785
# Epoch 115/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1963 - accuracy: 0.9260 - val_loss: 0.0787 - val_accuracy: 0.9785
# Epoch 116/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1869 - accuracy: 0.9282 - val_loss: 0.0716 - val_accuracy: 0.9824
# Epoch 117/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1818 - accuracy: 0.9299 - val_loss: 0.0733 - val_accuracy: 0.9785
# Epoch 118/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1944 - accuracy: 0.9209 - val_loss: 0.0796 - val_accuracy: 0.9785
# Epoch 119/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1834 - accuracy: 0.9285 - val_loss: 0.0748 - val_accuracy: 0.9795
# Epoch 120/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1761 - accuracy: 0.9309 - val_loss: 0.0763 - val_accuracy: 0.9785
# Epoch 121/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1777 - accuracy: 0.9292 - val_loss: 0.0770 - val_accuracy: 0.9805
# Epoch 122/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1898 - accuracy: 0.9285 - val_loss: 0.0715 - val_accuracy: 0.9775
# Epoch 123/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1796 - accuracy: 0.9329 - val_loss: 0.0735 - val_accuracy: 0.9785
# Epoch 124/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1773 - accuracy: 0.9356 - val_loss: 0.0719 - val_accuracy: 0.9795
# Epoch 125/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1836 - accuracy: 0.9292 - val_loss: 0.0692 - val_accuracy: 0.9795
# Epoch 126/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1703 - accuracy: 0.9341 - val_loss: 0.0649 - val_accuracy: 0.9785
# Epoch 127/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1680 - accuracy: 0.9302 - val_loss: 0.0787 - val_accuracy: 0.9775
# Epoch 128/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1861 - accuracy: 0.9243 - val_loss: 0.0629 - val_accuracy: 0.9805
# Epoch 129/130
# 17/17 [==============================] - 49s 3s/step - loss: 0.1708 - accuracy: 0.9341 - val_loss: 0.0765 - val_accuracy: 0.9775
# Epoch 130/130
# 17/17 [==============================] - 51s 3s/step - loss: 0.1821 - accuracy: 0.9304 - val_loss: 0.0730 - val_accuracy: 0.9814

# %%
# save the model
cnn.save('cnn.h5')

# %% [markdown]
# # Visualization

# %%
#visualization of the model evaluation
#plot image will change with more epochs
accuracy = cnn_history.history['accuracy']
val_accuracy = cnn_history.history['val_accuracy']
loss = cnn_history.history['loss']
val_loss = cnn_history.history['val_loss']
epochs = range(len(accuracy))

#Visualize the accuracy
plt.plot(epochs, accuracy, 'b', c = 'blue', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'b', c = 'orange', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.figure()

#Visualize the loss
plt.plot(epochs, loss, 'b', c = 'blue', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', c = 'orange', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluation

# %%
test_eval = cnn.evaluate(test_set, verbose = 0)

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 1.9542330503463745
# Test accuracy: 0.5817044377326965

# %% [markdown]
# # Classification Report

# %%
pred_classes = cnn.predict(test_set)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
pred_classes = np.argmax(np.round(pred_classes), axis = 1)

# %%
#create a classification report
target_names = ['Class {}'.format(i) for i in range(4)]
print(classification_report(test_labels, pred_classes, target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.12      0.03      0.05       179
#      Class 1       0.00      0.00      0.00        12
#      Class 2       0.49      0.46      0.48       640
#      Class 3       0.36      0.51      0.42       448
#
#     accuracy                           0.41      1279
#    macro avg       0.25      0.25      0.24      1279
# weighted avg       0.39      0.41      0.39      1279
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Confusion Matrix

# %%
# create confusion matrix
cm = confusion_matrix(test_labels, pred_classes)

# %%
# create a heatmap
plt.figure(figsize=(9, 9))

sns.heatmap(cm, 
            annot = True, 
            fmt = ".2f",
            square = True,
            yticklabels = class_names, 
            xticklabels = class_names)
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
all_sample_title = f'Model Accuracy Score: {test_eval[1]:.2%}'
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Model Accuracy Score: 58.17%')
